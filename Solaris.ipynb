# %%
# 🔧 1. 필수 패키지 설치
# !pip install flask pyngrok pvlib requests -q

# 🔧 2. ngrok 인증 토큰 설정 (https://dashboard.ngrok.com/get-started)
from pyngrok import ngrok
ngrok.set_auth_token("2wlRsXfCKutDoNMOYgqxUsb4OrG_4LaaHS1afAguEXJGfXXbC")  # ★ 필수!

from pyngrok import ngrok
ngrok.kill()

# 🌞 3. Flask 앱 + Leaflet 지도 실행
from flask import Flask, request, jsonify, render_template_string
import requests

app = Flask(__name__)

@app.route('/')
def index():
    return render_template_string("""
    <!DOCTYPE html>
    <html>
    <head>
      <meta charset="utf-8" />
      <title>태양광 발전량 지도 MVP</title>
      <meta name="viewport" content="width=device-width, initial-scale=1.0">
      <link rel="stylesheet" href="https://unpkg.com/leaflet/dist/leaflet.css" />
      <style>#map { height: 100vh; }</style>
    </head>
    <body>
    <div id="map"></div>

    <script src="https://unpkg.com/leaflet/dist/leaflet.js"></script>
    <script>
      const map = L.map('map').setView([36.5, 127.8], 7);
      L.tileLayer('https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', {
        attribution: '© OpenStreetMap contributors'
      }).addTo(map);

      function onMapClick(e) {
        const lat = e.latlng.lat.toFixed(5);
        const lon = e.latlng.lng.toFixed(5);
        fetch(`/get_pv_data?lat=${lat}&lon=${lon}`)
          .then(res => res.json())
          .then(data => {
            if (data.error) {
              L.popup().setLatLng(e.latlng).setContent("❌ 데이터 조회 오류").openOn(map);
            } else {
              L.popup().setLatLng(e.latlng)
                .setContent(
                  `📍 위도: ${lat}, 경도: ${lon}<br>` +
                  `☀️ 연평균 일사량: ${data.ghi} kWh/m²<br>` +
                  `⚡ 예상 발전량: ${data.energy} kWh/kWp`
                ).openOn(map);
            }
          });
      }

      map.on('click', onMapClick);
    </script>
    </body>
    </html>
    """)

@app.route('/get_pv_data')
def get_pv_data():
    lat = request.args.get('lat', type=float)
    lon = request.args.get('lon', type=float)

    url = (
        f'https://power.larc.nasa.gov/api/temporal/climatology/point'
        f'?parameters=ALLSKY_SFC_SW_DWN&community=RE&latitude={lat}&longitude={lon}&format=JSON'
    )

    res = requests.get(url).json()
    try:
        ghi = res['properties']['parameter']['ALLSKY_SFC_SW_DWN']['ANN']
    except KeyError:
        return jsonify({'error': 'GHI data not found'}), 500

    energy = ghi * 0.85  # 시스템 손실 고려 (15%)
    
    return jsonify({'ghi': round(ghi, 1), 'energy': round(energy, 1)})

# 🚀 4. ngrok 터널 열고 앱 실행
public_url = ngrok.connect(5000)
print(f"\n🌍 여기에 접속하세요: {public_url}\n")
app.run(port=5000)
# Out:
# 🌍 여기에 접속하세요: NgrokTunnel: "https://9ca2-106-101-3-139.ngrok-free.app" -> "http://localhost:5000"
#
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [07/May/2025 20:01:54] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [07/May/2025 20:02:01] "GET /get_pv_data?lat=36.79279&lon=127.89871 HTTP/1.1" 200 -
# 127.0.0.1 - - [07/May/2025 20:02:02] "GET /get_pv_data?lat=36.79224&lon=127.84653 HTTP/1.1" 200 -
# 127.0.0.1 - - [07/May/2025 20:02:04] "GET /get_pv_data?lat=36.79279&lon=127.89871 HTTP/1.1" 200 -
# 127.0.0.1 - - [07/May/2025 20:02:05] "GET /get_pv_data?lat=36.78234&lon=127.90421 HTTP/1.1" 200 -
# 127.0.0.1 - - [07/May/2025 20:02:05] "GET /get_pv_data?lat=36.79224&lon=127.84653 HTTP/1.1" 200 -
# 127.0.0.1 - - [07/May/2025 20:02:08] "GET /get_pv_data?lat=36.79224&lon=127.84653 HTTP/1.1" 200 -
# 127.0.0.1 - - [07/May/2025 20:02:10] "GET /get_pv_data?lat=36.79224&lon=127.84653 HTTP/1.1" 200 -
# 127.0.0.1 - - [07/May/2025 20:02:13] "GET /get_pv_data?lat=36.83539&lon=127.69547 HTTP/1.1" 200 -
# 127.0.0.1 - - [07/May/2025 20:02:13] "GET /get_pv_data?lat=36.79224&lon=127.84653 HTTP/1.1" 200 -
# 127.0.0.1 - - [07/May/2025 20:02:16] "GET /get_pv_data?lat=36.79224&lon=127.84653 HTTP/1.1" 200 -
# 127.0.0.1 - - [07/May/2025 20:02:18] "GET /get_pv_data?lat=36.83649&lon=127.71126 HTTP/1.1" 200 -
# 127.0.0.1 - - [07/May/2025 20:02:18] "GET /get_pv_data?lat=36.79224&lon=127.84653 HTTP/1.1" 200 -
# 127.0.0.1 - - [07/May/2025 20:02:21] "GET /get_pv_data?lat=36.79224&lon=127.84653 HTTP/1.1" 200 -
# 127.0.0.1 - - [07/May/2025 20:02:29] "GET /get_pv_data?lat=37.04285&lon=127.19421 HTTP/1.1" 200 -
# 127.0.0.1 - - [07/May/2025 20:02:30] "GET /get_pv_data?lat=37.04339&lon=127.19421 HTTP/1.1" 200 -
# 127.0.0.1 - - [07/May/2025 20:02:33] "GET /get_pv_data?lat=37.04339&lon=127.19421 HTTP/1.1" 200 -
# 127.0.0.1 - - [07/May/2025 20:02:52] "GET /get_pv_data?lat=37.03764&lon=127.41806 HTTP/1.1" 200 -
# t=2025-05-07T20:15:41+0900 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=ddd27e99b433 err="read tcp 192.168.114.101:61920->3.12.62.205:443: wsarecv: An established connection was aborted by the software in your host machine."
# t=2025-05-07T20:15:41+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp: lookup connect.us.ngrok-agent.com: no such host"
# t=2025-05-07T20:15:47+0900 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=e1c331adb2b5 clientid=c3886a2d626f93340876f4a488471791
# t=2025-05-07T20:15:52+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.16.250.205:443: i/o timeout"
# t=2025-05-07T20:16:03+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.16.250.205:443: i/o timeout"
# t=2025-05-07T20:16:15+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.16.250.205:443: i/o timeout"
# t=2025-05-07T20:16:29+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.16.250.205:443: i/o timeout"
# t=2025-05-07T20:16:47+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.16.250.205:443: i/o timeout"
# t=2025-05-07T20:17:13+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.136.132.147:443: i/o timeout"
# t=2025-05-07T20:17:53+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.136.132.147:443: i/o timeout"
# t=2025-05-07T20:18:33+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.16.250.205:443: i/o timeout"
# t=2025-05-07T20:19:13+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.16.250.205:443: i/o timeout"
# t=2025-05-07T20:19:53+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.16.250.205:443: i/o timeout"
# t=2025-05-07T20:20:33+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.16.250.205:443: i/o timeout"
# t=2025-05-07T20:21:13+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.133.228.214:443: i/o timeout"
# t=2025-05-07T20:21:53+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.133.228.214:443: i/o timeout"
# t=2025-05-07T20:22:33+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.136.132.147:443: i/o timeout"
# t=2025-05-07T20:23:13+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.136.132.147:443: i/o timeout"
# t=2025-05-07T20:23:53+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.133.228.214:443: i/o timeout"
# t=2025-05-07T20:24:33+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.133.228.214:443: i/o timeout"
# t=2025-05-07T20:25:13+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.16.250.205:443: i/o timeout"
# t=2025-05-07T20:25:53+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.16.250.205:443: i/o timeout"
# t=2025-05-07T20:26:33+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.134.73.173:443: i/o timeout"
# t=2025-05-07T20:27:13+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.134.73.173:443: i/o timeout"
# t=2025-05-07T20:27:53+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.136.132.147:443: i/o timeout"
# t=2025-05-07T20:28:33+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.136.132.147:443: i/o timeout"
# t=2025-05-07T20:29:13+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.16.250.205:443: i/o timeout"
# t=2025-05-07T20:29:53+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.16.250.205:443: i/o timeout"
# t=2025-05-07T20:30:33+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.12.62.205:443: i/o timeout"
# t=2025-05-07T20:31:13+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.12.62.205:443: i/o timeout"
# t=2025-05-07T20:31:53+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.136.132.147:443: i/o timeout"
# t=2025-05-07T20:32:33+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.136.132.147:443: i/o timeout"
# t=2025-05-07T20:33:13+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.134.73.173:443: i/o timeout"
# t=2025-05-07T20:33:53+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.134.73.173:443: i/o timeout"
# t=2025-05-07T20:34:33+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.133.228.214:443: i/o timeout"
# t=2025-05-07T20:35:13+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.133.228.214:443: i/o timeout"
# t=2025-05-07T20:35:53+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.134.73.173:443: i/o timeout"
# t=2025-05-07T20:36:33+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.134.73.173:443: i/o timeout"
# t=2025-05-07T20:37:13+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.133.228.214:443: i/o timeout"
# t=2025-05-07T20:37:53+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.133.228.214:443: i/o timeout"
# t=2025-05-07T20:38:33+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.134.73.173:443: i/o timeout"
# t=2025-05-07T20:39:13+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.134.73.173:443: i/o timeout"
# t=2025-05-07T20:39:53+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.133.228.214:443: i/o timeout"
# t=2025-05-07T20:40:33+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.133.228.214:443: i/o timeout"
# t=2025-05-07T20:41:13+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.16.250.205:443: i/o timeout"
# t=2025-05-07T20:41:53+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.16.250.205:443: i/o timeout"
# t=2025-05-07T20:42:33+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.20.27.198:443: i/o timeout"
# t=2025-05-07T20:43:13+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.20.27.198:443: i/o timeout"
# t=2025-05-07T20:43:53+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.136.132.147:443: i/o timeout"
# t=2025-05-07T20:44:33+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.136.132.147:443: i/o timeout"
# t=2025-05-07T20:45:13+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.16.250.205:443: i/o timeout"
# t=2025-05-07T20:45:53+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.16.250.205:443: i/o timeout"
# t=2025-05-07T20:46:33+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.16.250.205:443: i/o timeout"
# t=2025-05-07T20:47:13+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.16.250.205:443: i/o timeout"
# t=2025-05-07T20:47:53+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.134.73.173:443: i/o timeout"
# t=2025-05-07T20:48:33+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.134.73.173:443: i/o timeout"
# t=2025-05-07T20:49:13+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.133.228.214:443: i/o timeout"
# t=2025-05-07T20:49:53+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.133.228.214:443: i/o timeout"
# t=2025-05-07T20:50:33+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.20.27.198:443: i/o timeout"
# t=2025-05-07T20:51:13+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.20.27.198:443: i/o timeout"
# t=2025-05-07T20:51:53+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.134.73.173:443: i/o timeout"
# t=2025-05-07T20:52:33+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.134.73.173:443: i/o timeout"
# t=2025-05-07T20:53:13+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.20.27.198:443: i/o timeout"
# 127.0.0.1 - - [07/May/2025 20:53:22] "GET /get_pv_data?lat=37.00475&lon=127.52380 HTTP/1.1" 200 -
# 127.0.0.1 - - [07/May/2025 20:53:22] "GET /get_pv_data?lat=36.98720&lon=127.66388 HTTP/1.1" 200 -
# t=2025-05-07T20:53:53+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.20.27.198:443: i/o timeout"
# t=2025-05-07T20:54:33+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.20.27.198:443: i/o timeout"
# t=2025-05-07T20:55:13+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.20.27.198:443: i/o timeout"
# t=2025-05-07T20:55:53+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.133.228.214:443: i/o timeout"
# t=2025-05-07T20:56:33+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.133.228.214:443: i/o timeout"
# t=2025-05-07T20:57:13+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.134.73.173:443: i/o timeout"
# t=2025-05-07T20:57:53+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.134.73.173:443: i/o timeout"
# t=2025-05-07T20:58:33+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.16.250.205:443: i/o timeout"
# t=2025-05-07T20:59:13+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.16.250.205:443: i/o timeout"
# t=2025-05-07T20:59:53+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.12.62.205:443: i/o timeout"
# t=2025-05-07T21:00:33+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.12.62.205:443: i/o timeout"
# t=2025-05-07T21:01:13+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.16.250.205:443: i/o timeout"
# t=2025-05-07T21:01:53+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.16.250.205:443: i/o timeout"
# t=2025-05-07T21:02:33+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.16.250.205:443: i/o timeout"
# t=2025-05-07T21:03:13+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.16.250.205:443: i/o timeout"
# t=2025-05-07T21:03:53+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.136.132.147:443: i/o timeout"
# t=2025-05-07T21:04:33+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.136.132.147:443: i/o timeout"
# t=2025-05-07T21:05:13+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.20.27.198:443: i/o timeout"
# t=2025-05-07T21:05:53+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.20.27.198:443: i/o timeout"
# t=2025-05-07T21:06:33+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.20.27.198:443: i/o timeout"
# t=2025-05-07T21:07:13+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.20.27.198:443: i/o timeout"
# t=2025-05-07T21:07:53+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.16.250.205:443: i/o timeout"
# t=2025-05-07T21:08:33+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.16.250.205:443: i/o timeout"
# t=2025-05-07T21:09:13+0900 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.133.228.214:443: i/o timeout"

# %%
# !pip install flask pyngrok requests -q

from pyngrok import ngrok
ngrok.set_auth_token("2wlRsXfCKutDoNMOYgqxUsb4OrG_4LaaHS1afAguEXJGfXXbC")  # https://dashboard.ngrok.com/get-started/your-authtoken
# Out:
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests, time, json

def frange(start, stop, step):
    while start <= stop:
        yield round(start, 2)
        start += step

lat_range = list(frange(33.0, 38.0, 0.5))
lon_range = list(frange(126.0, 130.0, 0.5))

heat_data = []

for lat in lat_range:
    for lon in lon_range:
        url = (
            f'https://power.larc.nasa.gov/api/temporal/climatology/point'
            f'?parameters=ALLSKY_SFC_SW_DWN&community=RE&latitude={lat}&longitude={lon}&format=JSON'
        )
        try:
            res = requests.get(url).json()
            ghi = res['properties']['parameter']['ALLSKY_SFC_SW_DWN']['ANN']
            intensity = round(ghi / 1600, 3)  # 0~1 범위 정규화
            heat_data.append([lat, lon, intensity])
            print(f"{lat}, {lon} → GHI: {ghi}")
        except:
            print(f"❌ 실패: {lat}, {lon}")
        time.sleep(1)

# JSON 저장
with open("heat_data.json", "w") as f:
    json.dump(heat_data, f)
# Out:
# 33.0, 126.0 → GHI: 3.78
# 33.0, 126.5 → GHI: 3.78
# 33.0, 127.0 → GHI: 3.91
# 33.0, 127.5 → GHI: 3.91
# 33.0, 128.0 → GHI: 3.93
# 33.0, 128.5 → GHI: 3.93
# 33.0, 129.0 → GHI: 3.79
# 33.0, 129.5 → GHI: 3.79
# 33.0, 130.0 → GHI: 3.79
# 33.5, 126.0 → GHI: 3.78
# 33.5, 126.5 → GHI: 3.78
# 33.5, 127.0 → GHI: 3.91
# 33.5, 127.5 → GHI: 3.91
# 33.5, 128.0 → GHI: 3.93
# 33.5, 128.5 → GHI: 3.93
# 33.5, 129.0 → GHI: 3.79
# 33.5, 129.5 → GHI: 3.79
# 33.5, 130.0 → GHI: 3.79
# 34.0, 126.0 → GHI: 3.89
# 34.0, 126.5 → GHI: 3.89
# 34.0, 127.0 → GHI: 3.98
# 34.0, 127.5 → GHI: 3.98
# 34.0, 128.0 → GHI: 4.04
# 34.0, 128.5 → GHI: 4.04
# 34.0, 129.0 → GHI: 3.88
# 34.0, 129.5 → GHI: 3.88
# 34.0, 130.0 → GHI: 3.84
# 34.5, 126.0 → GHI: 3.89
# 34.5, 126.5 → GHI: 3.89
# 34.5, 127.0 → GHI: 3.98
# 34.5, 127.5 → GHI: 3.98
# 34.5, 128.0 → GHI: 4.04
# 34.5, 128.5 → GHI: 4.04
# 34.5, 129.0 → GHI: 3.88
# 34.5, 129.5 → GHI: 3.88
# 34.5, 130.0 → GHI: 3.84
# 35.0, 126.0 → GHI: 3.83
# 35.0, 126.5 → GHI: 3.83
# 35.0, 127.0 → GHI: 3.9
# 35.0, 127.5 → GHI: 3.9
# 35.0, 128.0 → GHI: 4.0
# 35.0, 128.5 → GHI: 4.0
# 35.0, 129.0 → GHI: 3.88
# 35.0, 129.5 → GHI: 3.88
# 35.0, 130.0 → GHI: 3.97
# 35.5, 126.0 → GHI: 3.83
# 35.5, 126.5 → GHI: 3.83
# 35.5, 127.0 → GHI: 3.9
# 35.5, 127.5 → GHI: 3.9
# 35.5, 128.0 → GHI: 4.0
# 35.5, 128.5 → GHI: 4.0
# 35.5, 129.0 → GHI: 3.88
# 35.5, 129.5 → GHI: 3.88
# 35.5, 130.0 → GHI: 3.97
# 36.0, 126.0 → GHI: 3.88
# 36.0, 126.5 → GHI: 3.88
# 36.0, 127.0 → GHI: 3.85
# 36.0, 127.5 → GHI: 3.85
# 36.0, 128.0 → GHI: 3.94
# 36.0, 128.5 → GHI: 3.94
# 36.0, 129.0 → GHI: 3.85
# 36.0, 129.5 → GHI: 3.85
# 36.0, 130.0 → GHI: 3.94
# 36.5, 126.0 → GHI: 3.88
# 36.5, 126.5 → GHI: 3.88
# 36.5, 127.0 → GHI: 3.85
# 36.5, 127.5 → GHI: 3.85
# 36.5, 128.0 → GHI: 3.94
# 36.5, 128.5 → GHI: 3.94
# 36.5, 129.0 → GHI: 3.85
# 36.5, 129.5 → GHI: 3.85
# 36.5, 130.0 → GHI: 3.94
# 37.0, 126.0 → GHI: 3.89
# 37.0, 126.5 → GHI: 3.89
# 37.0, 127.0 → GHI: 3.79
# 37.0, 127.5 → GHI: 3.79
# 37.0, 128.0 → GHI: 3.79
# 37.0, 128.5 → GHI: 3.79
# 37.0, 129.0 → GHI: 3.77
# 37.0, 129.5 → GHI: 3.77
# 37.0, 130.0 → GHI: 3.8
# 37.5, 126.0 → GHI: 3.89
# 37.5, 126.5 → GHI: 3.89
# 37.5, 127.0 → GHI: 3.79
# 37.5, 127.5 → GHI: 3.79
# 37.5, 128.0 → GHI: 3.79
# 37.5, 128.5 → GHI: 3.79
# 37.5, 129.0 → GHI: 3.77
# 37.5, 129.5 → GHI: 3.77
# 37.5, 130.0 → GHI: 3.8
# 38.0, 126.0 → GHI: 3.83
# 38.0, 126.5 → GHI: 3.83
# 38.0, 127.0 → GHI: 3.77
# 38.0, 127.5 → GHI: 3.77
# 38.0, 128.0 → GHI: 3.73
# 38.0, 128.5 → GHI: 3.73
# 38.0, 129.0 → GHI: 3.88
# 38.0, 129.5 → GHI: 3.88
# 38.0, 130.0 → GHI: 3.8

# %%
from flask import Flask, send_file, render_template_string
from pyngrok import ngrok

app = Flask(__name__)

@app.route('/')
def index():
    return render_template_string("""
    <!DOCTYPE html>
    <html>
    <head>
      <meta charset="utf-8" />
      <title>태양광 히트맵</title>
      <meta name="viewport" content="width=device-width, initial-scale=1.0">
      <link rel="stylesheet" href="https://unpkg.com/leaflet/dist/leaflet.css" />
      <style>#map { height: 100vh; }</style>
    </head>
    <body>
    <div id="map"></div>

    <script src="https://unpkg.com/leaflet/dist/leaflet.js"></script>
    <script src="https://unpkg.com/leaflet.heat/dist/leaflet-heat.js"></script>

    <script>
      const map = L.map('map').setView([36.5, 127.8], 7);
      L.tileLayer('https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', {
        attribution: '© OpenStreetMap contributors'
      }).addTo(map);

      fetch('/heat_data.json')
        .then(res => res.json())
        .then(data => {
          L.heatLayer(data, {radius: 30}).addTo(map);
        });
    </script>
    </body>
    </html>
    """)

@app.route('/heat_data.json')
def heatmap_json():
    return send_file('heat_data.json', mimetype='application/json')

public_url = ngrok.connect(5000)
print(f"🔗 접속 링크: {public_url}")
app.run(port=5000)
# Out:
# 🔗 접속 링크: NgrokTunnel: "https://7d6b-106-101-3-139.ngrok-free.app" -> "http://localhost:5000"
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [07/May/2025 20:00:10] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [07/May/2025 20:00:10] "GET /heat_data.json HTTP/1.1" 200 -
